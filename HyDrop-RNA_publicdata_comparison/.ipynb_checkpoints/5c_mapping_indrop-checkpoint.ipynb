# %% [markdown]
# # first, generate a barcode read from read 2, 3, 4

# %% [markdown]
# basically followed this: https://github.com/alexdobin/STAR/issues/825

# %%
module load mawk
for file in fastq_indrop/*_1.fastq.gz
do
    echo $file
    sample=`basename ${file%_1.fastq.gz}`
    echo $sample
    SAMPLE_R2=fastq_indrop/${sample}_2.fastq.gz
    SAMPLE_R4=fastq_indrop/${sample}_4.fastq.gz
    SAMPLE_R24=fastq_indrop/${sample}_24.fastq.gz
    echo $SAMPLE_R24
    paste <(zcat ${SAMPLE_R2}) <(zcat ${SAMPLE_R4}) | mawk '{if (NR%4==1) {print $1 " 2:4:paste"} else if (NR%4==3) {print $1} else {print $1 $2}}' | gzip > ${SAMPLE_R24} &
done

# %%
jobs

# %%
paste \ 
    <(zcat ${SAMPLE_R2}) \
    <(zcat ${SAMPLE_R3}) \
    <(zcat ${SAMPLE_R4}) \
    | mawk '{if ((NR%4==1) && ($1 == $3) && ($3 == $5)) {print $1 " 2:3:4:paste"} else if ((NR%4==1) && ($1 != $3)) {print "singleton"} else if ((NR%4==1) && ($3 != $5)) {print "singleton"} else if (NR%4==3) {print $1} else {print $1 $2 $3}}' \
    | gzip > ${SAMPLE_R234.fastq.gz}

# %% [markdown]
# # then, generate bc list

# %%
module load mawk
cartesian(){
awk -F '\t' \
    -v "bc1_list=$1" \
    -v "bc2_list=$2" '
    {
        if ( FILENAME == bc1_list ) {
            BC1[$0];
        }
        else if ( FILENAME == bc2_list ) {
             BC2[$0];
        }
    } END {
        for (bc1 in BC1) {
           for (bc2 in BC2) {
               print bc1 bc2
           }
        }
     } ' $1 $2 > $3
}

# %%
cat 20220127_indrop_barcodes_kalish_384x384/gel_barcode2_list.txt | tr 'ACGT' 'TGCA' | rev > 20220127_indrop_barcodes_kalish_384x384/gel_barcode2_list_revcomp.txt

# %%
cartesian 20220127_indrop_barcodes_kalish_384x384/gel_barcode2_list.txt 20220127_indrop_barcodes_kalish_384x384/gel_barcode2_list_revcomp.txt 20220127_indrop_barcodes_kalish_384x384/full_whitelist

# %% [markdown]
# # then map

# %% [markdown]
# pos 1-8: bc1
# pos 9-16: 8 bp index
# pos 17-24: bc2 (reverse complement of whitelist)
# pos 25-30: UMI

# %%
star_solo_indrop_rna_mapping_unique_cellfilter () {
    local fastq_R1_filename="${1}";
    local fastq_R2_filename="${2}";
    local bam_filename="${3}";
    # 3 barcode lists:
    local whitelist_part1_filename='indrop_whitelist/gel_barcode2_list.txt';
    local whitelist_part2_filename='indrop_whitelist/index_whitelist.txt';
    local whitelist_part3_filename='indrop_whitelist/gel_barcode2_list_revcomp.txt';
    star_reference_dir='/lustre1/project/stg_00002/lcb/fderop/data/00000000_genomes/mm10_STAR_2.7.8_premrna';
    sjdbgtf='/lustre1/project/stg_00002/lcb/fderop/data/00000000_genomes/mm10_STAR_2.7.8_premrna/genes.gtf'
    #module load STAR/2.7.5b-foss-2018a;
    #module load SAMtools/1.10-foss-2018a;
    # Map with STAR solo
    /lustre1/project/stg_00002/lcb/fderop/scripts/STAR-2.7.8a/bin/Linux_x86_64/STAR \
        --runThreadN 32 \
        --runMode alignReads \
        --outSAMtype BAM SortedByCoordinate \
        --sysShell /bin/bash \
        --genomeDir "${star_reference_dir}" \
        --readFilesIn "${fastq_R1_filename}" "${fastq_R2_filename}" \
        --readFilesCommand 'gzip -c -d' \
        --soloCBwhitelist "${whitelist_part1_filename}" "${whitelist_part2_filename}" "${whitelist_part3_filename}" \
        --soloType CB_UMI_Complex \
        --soloCBposition 0_0_0_7 0_8_0_15 0_16_0_23 \
        --soloUMIposition 0_24_0_29 \
        --sjdbGTFfile $sjdbgtf \
        --soloCellFilter CellRanger2.2 2000 0.99 10 \
        --soloCBmatchWLtype 1MM \
        --outFilterMultimapNmax 1 \
        --outSAMattributes NH HI AS nM CB UB CR CY UR UY \
        --outFileNamePrefix ${bam_filename%bam} \
        --outReadsUnmapped Fastx \
        --quantMode GeneCounts \
        --bamRemoveDuplicatesType UniqueIdentical \
        --soloFeatures Gene GeneFull
        # Index BAM file.
    # samtools index "${bam_filename%bam}Aligned.sortedByCoord.out.bam"
}

# %% [markdown]
# Now we run this star solo script in a for loop on all the R2 fastq files in `fastq/`

# %%
dir=demultiplexed_indrop_index
mkdir $dir
for sample in fastq_indrop/*_1.fastq.gz
do
    NAME=${sample%_1.fastq.gz}
    OUT=${NAME##*/}
    echo $NAME
    star_solo_indrop_rna_mapping_unique_cellfilter \
        ${NAME}_1.fastq.gz \
        ${NAME}_234.fastq.gz \
        $dir/$OUT.bam
done
# Out:
# mkdir: cannot create directory ‘demultiplexed_indrop_index’: File exists
# fastq_indrop/SRR10545068
# Jan 31 16:59:55 ..... started STAR run
# Jan 31 16:59:55 ..... loading genome
# Jan 31 17:00:29 ..... processing annotations GTF
# Jan 31 17:00:35 ..... started mapping

# %% [markdown]
# Now, we can get a summary of the statistics below:

# %%
for sample in $dir/*/Gene/Summary.csv
do
    echo ${sample#*/}
    cat $sample
    cut -d, -f2 $sample > ${sample%/Gene/Summary.csv}/Gene/Summary_numbers.csv
    printf "\n"
done
# Out:
# SRR10545068.Solo.out/Gene/Summary.csv
# Number of Reads,136252173
# Reads With Valid Barcodes,0.440879
# Sequencing Saturation,0.266368
# Q30 Bases in CB+UMI,0.832998
# Q30 Bases in RNA read,0.800453
# Reads Mapped to Genome: Unique+Multiple,0.488978
# Reads Mapped to Genome: Unique,0.488978
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.301477
# Reads Mapped to Transcriptome: Unique Genes,0.293621
# Estimated Number of Cells,14363
# Reads in Cells Mapped to Unique Genes,24349722
# Fraction of Reads in Cells,0.608644
# Mean Reads per Cell,1695
# Median Reads per Cell,1432
# UMIs in Cells,17563343
# Mean UMI per Cell,1222
# Median UMI per Cell,1044
# Mean Genes per Cell,896
# Median Genes per Cell,806
# Total Genes Detected,21125
#
# SRR10545069.Solo.out/Gene/Summary.csv
# Number of Reads,103036640
# Reads With Valid Barcodes,0.381989
# Sequencing Saturation,0.196112
# Q30 Bases in CB+UMI,0.732578
# Q30 Bases in RNA read,0.711272
# Reads Mapped to Genome: Unique+Multiple,0.450167
# Reads Mapped to Genome: Unique,0.450167
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.249958
# Reads Mapped to Transcriptome: Unique Genes,0.243351
# Estimated Number of Cells,12538
# Reads in Cells Mapped to Unique Genes,14228154
# Fraction of Reads in Cells,0.567445
# Mean Reads per Cell,1134
# Median Reads per Cell,945
# UMIs in Cells,11255164
# Mean UMI per Cell,897
# Median UMI per Cell,755
# Mean Genes per Cell,692
# Median Genes per Cell,612
# Total Genes Detected,20384
#
# SRR10545070.Solo.out/Gene/Summary.csv
# Number of Reads,98859416
# Reads With Valid Barcodes,0.408675
# Sequencing Saturation,0.196926
# Q30 Bases in CB+UMI,0.746938
# Q30 Bases in RNA read,0.710311
# Reads Mapped to Genome: Unique+Multiple,0.447653
# Reads Mapped to Genome: Unique,0.447653
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.264455
# Reads Mapped to Transcriptome: Unique Genes,0.257502
# Estimated Number of Cells,12668
# Reads in Cells Mapped to Unique Genes,14533296
# Fraction of Reads in Cells,0.570907
# Mean Reads per Cell,1147
# Median Reads per Cell,955
# UMIs in Cells,11493802
# Mean UMI per Cell,907
# Median UMI per Cell,764
# Mean Genes per Cell,699
# Median Genes per Cell,619
# Total Genes Detected,20493
#
# SRR10545071.Solo.out/Gene/Summary.csv
# Number of Reads,100660676
# Reads With Valid Barcodes,0.391889
# Sequencing Saturation,0.195025
# Q30 Bases in CB+UMI,0.739465
# Q30 Bases in RNA read,0.712597
# Reads Mapped to Genome: Unique+Multiple,0.452498
# Reads Mapped to Genome: Unique,0.452498
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.255742
# Reads Mapped to Transcriptome: Unique Genes,0.248998
# Estimated Number of Cells,12618
# Reads in Cells Mapped to Unique Genes,14276253
# Fraction of Reads in Cells,0.569584
# Mean Reads per Cell,1131
# Median Reads per Cell,942
# UMIs in Cells,11315094
# Mean UMI per Cell,896
# Median UMI per Cell,756
# Mean Genes per Cell,692
# Median Genes per Cell,612
# Total Genes Detected,20449
#
# SRR10545072.Solo.out/Gene/Summary.csv
# Number of Reads,134789164
# Reads With Valid Barcodes,0.416603
# Sequencing Saturation,0.255584
# Q30 Bases in CB+UMI,0.817862
# Q30 Bases in RNA read,0.798391
# Reads Mapped to Genome: Unique+Multiple,0.483215
# Reads Mapped to Genome: Unique,0.483215
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.284974
# Reads Mapped to Transcriptome: Unique Genes,0.277531
# Estimated Number of Cells,14249
# Reads in Cells Mapped to Unique Genes,22663375
# Fraction of Reads in Cells,0.605839
# Mean Reads per Cell,1590
# Median Reads per Cell,1343
# UMIs in Cells,16585294
# Mean UMI per Cell,1163
# Median UMI per Cell,992
# Mean Genes per Cell,861
# Median Genes per Cell,775
# Total Genes Detected,21013
#
# SRR10545073.Solo.out/Gene/Summary.csv
# Number of Reads,130210119
# Reads With Valid Barcodes,0.439545
# Sequencing Saturation,0.25687
# Q30 Bases in CB+UMI,0.82782
# Q30 Bases in RNA read,0.791933
# Reads Mapped to Genome: Unique+Multiple,0.48634
# Reads Mapped to Genome: Unique,0.48634
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.299095
# Reads Mapped to Transcriptome: Unique Genes,0.29128
# Estimated Number of Cells,14411
# Reads in Cells Mapped to Unique Genes,23105678
# Fraction of Reads in Cells,0.609205
# Mean Reads per Cell,1603
# Median Reads per Cell,1354
# UMIs in Cells,16891716
# Mean UMI per Cell,1172
# Median UMI per Cell,1001
# Mean Genes per Cell,866
# Median Genes per Cell,779
# Total Genes Detected,21100
#
# SRR10545074.Solo.out/Gene/Summary.csv
# Number of Reads,131473567
# Reads With Valid Barcodes,0.422575
# Sequencing Saturation,0.253033
# Q30 Bases in CB+UMI,0.821877
# Q30 Bases in RNA read,0.796305
# Reads Mapped to Genome: Unique+Multiple,0.485901
# Reads Mapped to Genome: Unique,0.485901
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.288511
# Reads Mapped to Transcriptome: Unique Genes,0.280963
# Estimated Number of Cells,14248
# Reads in Cells Mapped to Unique Genes,22386739
# Fraction of Reads in Cells,0.606043
# Mean Reads per Cell,1571
# Median Reads per Cell,1327
# UMIs in Cells,16443474
# Mean UMI per Cell,1154
# Median UMI per Cell,985
# Mean Genes per Cell,855
# Median Genes per Cell,767
# Total Genes Detected,20962
#
# SRR10545075.Solo.out/Gene/Summary.csv
# Number of Reads,125843005
# Reads With Valid Barcodes,0.437122
# Sequencing Saturation,0.259587
# Q30 Bases in CB+UMI,0.801609
# Q30 Bases in RNA read,0.767215
# Reads Mapped to Genome: Unique+Multiple,0.496859
# Reads Mapped to Genome: Unique,0.496859
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.300357
# Reads Mapped to Transcriptome: Unique Genes,0.292619
# Estimated Number of Cells,13365
# Reads in Cells Mapped to Unique Genes,21844268
# Fraction of Reads in Cells,0.593206
# Mean Reads per Cell,1634
# Median Reads per Cell,1363
# UMIs in Cells,15840113
# Mean UMI per Cell,1185
# Median UMI per Cell,1006
# Mean Genes per Cell,872
# Median Genes per Cell,781
# Total Genes Detected,21070
#
# SRR10545076.Solo.out/Gene/Summary.csv
# Number of Reads,125597295
# Reads With Valid Barcodes,0.413883
# Sequencing Saturation,0.25111
# Q30 Bases in CB+UMI,0.792616
# Q30 Bases in RNA read,0.773506
# Reads Mapped to Genome: Unique+Multiple,0.492923
# Reads Mapped to Genome: Unique,0.492923
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.284902
# Reads Mapped to Transcriptome: Unique Genes,0.277517
# Estimated Number of Cells,13375
# Reads in Cells Mapped to Unique Genes,20680261
# Fraction of Reads in Cells,0.593316
# Mean Reads per Cell,1546
# Median Reads per Cell,1292
# UMIs in Cells,15173551
# Mean UMI per Cell,1134
# Median UMI per Cell,966
# Mean Genes per Cell,841
# Median Genes per Cell,754
# Total Genes Detected,20931
#
# SRR10545077.Solo.out/Gene/Summary.csv
# Number of Reads,120173234
# Reads With Valid Barcodes,0.434949
# Sequencing Saturation,0.250247
# Q30 Bases in CB+UMI,0.795757
# Q30 Bases in RNA read,0.757655
# Reads Mapped to Genome: Unique+Multiple,0.492646
# Reads Mapped to Genome: Unique,0.492646
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.297433
# Reads Mapped to Transcriptome: Unique Genes,0.289762
# Estimated Number of Cells,13386
# Reads in Cells Mapped to Unique Genes,20666879
# Fraction of Reads in Cells,0.593506
# Mean Reads per Cell,1543
# Median Reads per Cell,1289
# UMIs in Cells,15190497
# Mean UMI per Cell,1134
# Median UMI per Cell,963
# Mean Genes per Cell,842
# Median Genes per Cell,755
# Total Genes Detected,20932
#
# SRR10545078.Solo.out/Gene/Summary.csv
# Number of Reads,121251623
# Reads With Valid Barcodes,0.411885
# Sequencing Saturation,0.24297
# Q30 Bases in CB+UMI,0.785203
# Q30 Bases in RNA read,0.752037
# Reads Mapped to Genome: Unique+Multiple,0.490856
# Reads Mapped to Genome: Unique,0.490856
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.28258
# Reads Mapped to Transcriptome: Unique Genes,0.275263
# Estimated Number of Cells,13247
# Reads in Cells Mapped to Unique Genes,19696659
# Fraction of Reads in Cells,0.590144
# Mean Reads per Cell,1486
# Median Reads per Cell,1241
# UMIs in Cells,14612934
# Mean UMI per Cell,1103
# Median UMI per Cell,936
# Mean Genes per Cell,822
# Median Genes per Cell,735
# Total Genes Detected,20880
#
# SRR10545079.Solo.out/Gene/Summary.csv
# Number of Reads,100751546
# Reads With Valid Barcodes,0.407114
# Sequencing Saturation,0.200409
# Q30 Bases in CB+UMI,0.737365
# Q30 Bases in RNA read,0.707794
# Reads Mapped to Genome: Unique+Multiple,0.454444
# Reads Mapped to Genome: Unique,0.454444
# Reads Mapped to Transcriptome: Unique+Multipe Genes,0.265971
# Reads Mapped to Transcriptome: Unique Genes,0.258983
# Estimated Number of Cells,12834
# Reads in Cells Mapped to Unique Genes,14979983
# Fraction of Reads in Cells,0.574102
# Mean Reads per Cell,1167
# Median Reads per Cell,971
# UMIs in Cells,11792879
# Mean UMI per Cell,918
# Median UMI per Cell,774
# Mean Genes per Cell,706
# Median Genes per Cell,625
# Total Genes Detected,20515
