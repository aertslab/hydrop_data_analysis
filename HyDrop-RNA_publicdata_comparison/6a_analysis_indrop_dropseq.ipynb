# %% [markdown]
# Most of the steps below have been copied from the scanpy tutorial: https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html

# %%
import numpy as np
import pandas as pd
import scanpy as sc

# %%
sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=150, facecolor="white", vector_friendly=False)
# Out:
# scanpy==1.8.1 anndata==0.7.5 umap==0.5.1 numpy==1.20.2 scipy==1.6.2 pandas==1.3.3 scikit-learn==0.24.1 statsmodels==0.12.2 python-igraph==0.9.0 leidenalg==0.8.3 pynndescent==0.5.2

# %% [markdown]
# Make sure that the packages that you have match the ones below IF you want to verify our results and obtain exactly the same results as described below. If you want to simply analyse your own dataset, then most likely later versions will also be fine.

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -----------------
# adjustText                         0.7.3
# aiohttp                            3.7.4.post0
# aiohttp-cors                       0.7.0
# aioredis                           1.3.1
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# anndata                            0.7.5
# annoy                              1.17.0
# ansiwrap                           0.8.4
# anyio                              2.2.0
# appdirs                            1.4.4
# arboreto                           0.1.6
# argcomplete                        1.12.2
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asciitree                          0.3.3
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            3.2.1
# async-timeout                      3.0.1
# atomicwrites                       1.4.0
# attrs                              20.3.0
# awscli                             1.22.48
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bap-atac                           0.6.7
# bash-kernel                        0.7.2
# bbknn                              1.4.0
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bgzip                              0.3.5
# bhtsne                             0.1.9
# biopython                          1.77
# bitarray                           1.6.3
# bkcharts                           0.2
# black                              20.8b1
# bleach                             3.3.0
# blessings                          1.7
# blis                               0.7.4
# bokeh                              2.3.0
# boltons                            20.2.1
# boto                               2.49.0
# boto3                              1.20.48
# botocore                           1.23.48
# Bottleneck                         1.3.2
# Brotli                             1.0.9
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         4.2.1
# cairocffi                          1.3.0
# catalogue                          1.0.0
# certifi                            2021.10.8
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# colorful                           0.5.4
# conda                              4.11.0
# conda-build                        3.18.8
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# ConfigArgParse                     1.2.3
# contextlib2                        0.6.0.post1
# cooler                             0.8.11
# coverage                           6.3.1
# cryptography                       3.3.1
# cssselect2                         0.4.1
# ctxcore                            0.1.1
# cycler                             0.10.0
# cymem                              2.0.5
# Cython                             0.29.22
# cytoolz                            0.10.1
# dask                               2021.3.1
# datrie                             0.8.2
# decorator                          4.4.2
# deepTools                          3.5.1
# deeptoolsintervals                 0.1.9
# defusedxml                         0.6.0
# deprecation                        2.1.0
# dill                               0.3.4.dev0
# distributed                        2021.3.1
# docutils                           0.16
# ecdsa                              0.18.0b2
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# fastcluster                        1.2.4
# fastkde                            1.0.19
# fbpca                              1.0
# filelock                           3.0.12
# Flask                              1.1.2
# fonttools                          4.29.1
# frozendict                         1.2
# fsspec                             0.8.7
# future                             0.18.2
# fuzzysearch                        0.7.3
# gensim                             3.8.3
# geosketch                          1.2
# germalemma                         0.1.3
# get-version                        2.1
# gevent                             21.1.1
# gitdb                              4.0.5
# GitPython                          3.1.3
# glob2                              0.7
# globre                             0.1.5
# gmpy2                              2.0.8
# google-api-core                    1.26.1
# google-auth                        1.27.1
# googleapis-common-protos           1.53.0
# gpustat                            0.6.0
# greenlet                           1.0.0
# grpcio                             1.36.1
# gspread                            3.1.0
# h5py                               3.2.1
# harmonypy                          0.0.5
# HeapDict                           1.0.1
# hiredis                            1.1.0
# html5lib                           1.1
# httplib2                           0.17.0
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# intel-openmp                       2020.0.133
# interlap                           0.2.7
# intervaltree                       2.1.0
# ipykernel                          5.5.0
# ipympl                             0.7.0
# ipython                            7.21.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.7.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.18.0
# jeepney                            0.6.0
# jgraph                             0.2.1
# Jinja2                             2.11.3
# jmespath                           0.10.0
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.0.1
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.2.0
# jupyter-contrib-core               0.3.3
# jupyter-contrib-nbextensions       0.5.1
# jupyter-core                       4.7.1
# jupyter-highlight-selected-word    0.2.0
# jupyter-latex-envs                 1.4.6
# jupyter-nbextensions-configurator  0.4.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.5.1
# jupyterlab                         3.0.12
# jupyterlab-code-formatter          1.4.5
# jupyterlab-server                  2.3.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.2.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.5.2
# lda                                2.0.0
# legacy-api-wrap                    1.2
# leidenalg                          0.8.3
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# loompy                             3.0.6
# loomxpy                            0.1.0
# lxml                               4.6.2
# MACS2                              2.2.6
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl                                2019.0
# mkl-fft                            1.3.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.1.0
# msgpack                            1.0.2
# multidict                          5.1.0
# multipledispatch                   0.6.0
# multiprocess                       0.70.11.1
# multiprocessing-on-dill            3.5.0a4
# murmurhash                         1.0.5
# mypy-extensions                    0.4.3
# natsort                            7.1.1
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.4
# nbconvert                          5.5.0
# nbformat                           5.1.3
# ncls                               0.0.57
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# nose2                              0.10.0
# notebook                           6.0.0
# numba                              0.53.1
# numexpr                            2.7.2
# numpy                              1.20.2
# numpy-groupies                     0.9.13
# numpydoc                           1.1.0
# nvidia-ml-py3                      7.352.0
# oauth2client                       4.1.3
# olefile                            0.46
# opencensus                         0.7.12
# opencensus-context                 0.1.2
# openpyxl                           3.0.6
# optparse-pretty                    0.1.1
# packaging                          20.9
# pandas                             1.3.3
# pandocfilters                      1.4.3
# papermill                          2.3.3
# paramiko                           2.9.2
# parso                              0.8.1
# partd                              1.1.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathos                             0.2.8.dev0
# pathspec                           0.8.1
# patsy                              0.5.1
# PatternLite                        3.6
# pbr                                3.1.1
# pep8                               1.7.1
# pexpect                            4.8.0
# PhenoGraph                         1.5.2
# pickleshare                        0.7.5
# Pillow                             8.1.2
# pip                                21.0.1
# pkginfo                            1.7.0
# plac                               1.1.3
# plotly                             4.14.3
# pluggy                             0.13.1
# ply                                3.11
# pox                                0.2.9
# ppft                               1.6.6.3
# preshed                            3.0.5
# prometheus-client                  0.9.0
# prompt-toolkit                     3.0.17
# protobuf                           3.15.5
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# py-spy                             0.3.4
# py2bit                             0.3.0
# pyarrow                            0.16.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pybedtools                         0.8.1
# pyBigWig                           0.3.18
# pybiomart                          0.2.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycrypto                           2.6.1
# pycurl                             7.43.0.6
# pydyf                              0.1.2
# pyfaidx                            0.5.9.5
# pyfasta                            0.5.2
# pyflakes                           2.2.0
# Pygments                           2.8.0
# pylint                             2.7.1
# PyNaCl                             1.5.0
# pynndescent                        0.5.2
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pypairix                           0.3.7
# pyparsing                          2.4.7
# Pyphen                             0.10.0
# pyranges                           0.0.95
# pyrle                              0.0.32
# pyrsistent                         0.17.3
# pysam                              0.15.3
# pyscenic                           0.11.2
# PySocks                            1.7.1
# pytest                             5.0.1
# pytest-arraydiff                   0.3
# pytest-astropy                     0.5.0
# pytest-doctestplus                 0.3.0
# pytest-openfiles                   0.3.2
# pytest-remotedata                  0.3.1
# python-dateutil                    2.8.1
# python-igraph                      0.9.0
# python-Levenshtein                 0.12.2
# python-louvain                     0.15
# python-oauth2                      1.1.1
# pytz                               2021.1
# PyWavelets                         1.1.1
# PyYAML                             5.4.1
# pyzmq                              22.0.3
# QtAwesome                          1.0.1
# qtconsole                          5.0.2
# QtPy                               1.9.0
# ratelimiter                        1.2.0.post0
# ray                                1.2.0
# redis                              3.5.3
# regex                              2020.11.13
# remote-ikernel                     0.4.6
# requests                           2.25.1
# requests-cache                     0.5.2
# retrying                           1.3.3
# rope                               0.18.0
# rsa                                4.7.2
# ruamel-yaml                        0.15.87
# ruamel.yaml                        0.16.10
# ruamel.yaml.clib                   0.2.0
# s3transfer                         0.5.1
# scanorama                          1.7.1
# scanpy                             1.8.1
# scikit-image                       0.17.2
# scikit-learn                       0.24.1
# scipy                              1.6.2
# scrublet                           0.2.3
# seaborn                            0.11.1
# SecretStorage                      3.3.1
# Send2Trash                         1.5.0
# seqc                               0.2.0
# setuptools                         54.2.0
# simplegeneric                      0.8.1
# simplejson                         3.17.2
# sinfo                              0.3.1
# singledispatch                     0.0.0
# sinto                              0.7.1
# six                                1.15.0
# sklearn                            0.0
# smart-open                         4.2.0
# smmap                              3.0.4
# snakemake                          5.19.3
# snaptools                          1.4.8
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sorted-nearest                     0.0.32
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2
# spacy                              2.3.5
# Sphinx                             3.5.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             3.3.6
# spyder-kernels                     0.5.1
# SQLAlchemy                         1.3.23
# srsly                              1.0.5
# statsmodels                        0.12.2
# stdlib-list                        0.8.0
# subsample                          0.0.6
# sympy                              1.7.1
# tables                             3.6.1
# tabulate                           0.8.9
# tblib                              1.7.0
# tenacity                           8.0.1
# terminado                          0.9.2
# testpath                           0.4.4
# texttable                          1.6.3
# textwrap3                          0.9.2
# thinc                              7.4.5
# threadpoolctl                      2.1.0
# tifffile                           2020.10.1
# tinycss2                           1.1.1
# tinydb                             4.6.1
# tmtoolkit                          0.9.0
# toml                               0.10.1
# toolz                              0.11.1
# toposort                           1.5
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typing                             3.7.4.3
# typing-extensions                  3.7.4.3
# umap                               0.1.1
# umap-learn                         0.5.1
# uncertainties                      3.1.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# wasabi                             0.8.2
# wcwidth                            0.2.5
# weasyprint                         54.1
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# wikipedia                          1.4.0
# wrapt                              1.12.1
# wurlitzer                          2.0.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.7
# xlwt                               1.3.0
# yarl                               1.6.3
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.2.0
# zopfli                             0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # drop-seq

# %%
import glob

# %%
mtx_dirs = sorted(glob.glob('demultiplexed_dropseq_sub/*Solo.out/Gene/raw/'))
mtx_dirs
# Out:
# ['demultiplexed_dropseq_sub/SRR1853178.Solo.out/Gene/raw/',
#  'demultiplexed_dropseq_sub/SRR1853179.Solo.out/Gene/raw/',
#  'demultiplexed_dropseq_sub/SRR1853180.Solo.out/Gene/raw/',
#  'demultiplexed_dropseq_sub/SRR1853181.Solo.out/Gene/raw/',
#  'demultiplexed_dropseq_sub/SRR1853182.Solo.out/Gene/raw/',
#  'demultiplexed_dropseq_sub/SRR1853183.Solo.out/Gene/raw/',
#  'demultiplexed_dropseq_sub/SRR1853184.Solo.out/Gene/raw/']

# %%
ncells_dict = {
    'SRR1853178': 6600,
    'SRR1853179': 9000,
    'SRR1853180': 6120,
    'SRR1853181': 7650,
    'SRR1853182': 7650,
    'SRR1853183': 8280,
    'SRR1853184': 4000,
}

# %%
for mtx_dir in mtx_dirs:
    sample=mtx_dir.replace('demultiplexed_dropseq_sub/', '')
    sample=sample.replace('.Solo.out/Gene/raw/', '')
    adata = sc.read_10x_mtx(
        mtx_dir,  # the directory with the `.mtx` file
        var_names="gene_symbols",  # use gene symbols for the variable names (variables-axis index)
        cache=True,
        )  # write a cache file for faster subsequent reading
    adata.obs_names = sample + '_' + adata.obs_names
    adata.var_names_make_unique()
    sc.pp.calculate_qc_metrics(adata, inplace=True)
    adata.obs.sort_values(by='n_genes_by_counts', ascending=False, inplace=True)
    ncells = ncells_dict[sample]
    adata = adata[0:ncells-1]
    adata.obs.to_csv(sample + '_adata.tsv', sep='\t', header=True)
# Out:
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853178.Solo.out-Gene-raw-matrix.h5ad
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853179.Solo.out-Gene-raw-matrix.h5ad
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853180.Solo.out-Gene-raw-matrix.h5ad
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853181.Solo.out-Gene-raw-matrix.h5ad
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853182.Solo.out-Gene-raw-matrix.h5ad
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853183.Solo.out-Gene-raw-matrix.h5ad
# ... reading from cache file cache/demultiplexed_dropseq_sub-SRR1853184.Solo.out-Gene-raw-matrix.h5ad

# %% [markdown]
# Merge into one nice dataframe:

# %%
df_merged = pd.DataFrame()
for file in glob.glob('tables/dropseq_SRR18531*_adata.tsv'):
    df = pd.read_csv(file, sep='\t', index_col=0)
    df_merged = df_merged.append(df)

# %%
df_merged
# Out:
#                          n_genes_by_counts  log1p_n_genes_by_counts  \
# SRR1853184_CTTTACTTGGTC               7713                 8.950792
# SRR1853184_CCGCTCTAAAAG               7506                 8.923591
# SRR1853184_CGGCACAGTGGA               7316                 8.897956
# SRR1853184_GATGCCGGAATG               6887                 8.837536
# SRR1853184_AGGGCTCGCGAC               6351                 8.756525
# ...                                    ...                      ...
# SRR1853181_GTCCGCGTCTCT                383                 5.950643
# SRR1853181_GGAAAACGACTG                383                 5.950643
# SRR1853181_GCCCAGAAATCT                383                 5.950643
# SRR1853181_TGGTGGGATCAC                383                 5.950643
# SRR1853181_GGCACAGAGCCA                383                 5.950643
#
#                          total_counts  log1p_total_counts  \
# SRR1853184_CTTTACTTGGTC       38554.0           10.559841
# SRR1853184_CCGCTCTAAAAG       45529.0           10.726127
# SRR1853184_CGGCACAGTGGA       33693.0           10.425076
# SRR1853184_GATGCCGGAATG       23715.0           10.073905
# SRR1853184_AGGGCTCGCGAC       29061.0           10.277186
# ...                               ...                 ...
# SRR1853181_GTCCGCGTCTCT         547.0            6.306275
# SRR1853181_GGAAAACGACTG         574.0            6.354370
# SRR1853181_GCCCAGAAATCT         454.0            6.120297
# SRR1853181_TGGTGGGATCAC         520.0            6.255750
# SRR1853181_GGCACAGAGCCA         477.0            6.169611
#
#                          pct_counts_in_top_50_genes  \
# SRR1853184_CTTTACTTGGTC                   14.229393
# SRR1853184_CCGCTCTAAAAG                   21.280942
# SRR1853184_CGGCACAGTGGA                   14.982341
# SRR1853184_GATGCCGGAATG                   10.221379
# SRR1853184_AGGGCTCGCGAC                   20.395031
# ...                                             ...
# SRR1853181_GTCCGCGTCTCT                   33.638026
# SRR1853181_GGAAAACGACTG                   33.972125
# SRR1853181_GCCCAGAAATCT                   26.651982
# SRR1853181_TGGTGGGATCAC                   31.730769
# SRR1853181_GGCACAGAGCCA                   30.188679
#
#                          pct_counts_in_top_100_genes  \
# SRR1853184_CTTTACTTGGTC                    19.248327
# SRR1853184_CCGCTCTAAAAG                    27.332030
# SRR1853184_CGGCACAGTGGA                    20.223785
# SRR1853184_GATGCCGGAATG                    15.306768
# SRR1853184_AGGGCTCGCGAC                    26.520078
# ...                                              ...
# SRR1853181_GTCCGCGTCTCT                    48.263254
# SRR1853181_GGAAAACGACTG                    50.696864
# SRR1853181_GCCCAGAAATCT                    37.665198
# SRR1853181_TGGTGGGATCAC                    45.576923
# SRR1853181_GGCACAGAGCCA                    40.670860
#
#                          pct_counts_in_top_200_genes  \
# SRR1853184_CTTTACTTGGTC                    26.280023
# SRR1853184_CCGCTCTAAAAG                    34.402249
# SRR1853184_CGGCACAGTGGA                    27.658564
# SRR1853184_GATGCCGGAATG                    22.230656
# SRR1853184_AGGGCTCGCGAC                    34.011218
# ...                                              ...
# SRR1853181_GTCCGCGTCTCT                    66.544790
# SRR1853181_GGAAAACGACTG                    68.118467
# SRR1853181_GCCCAGAAATCT                    59.691630
# SRR1853181_TGGTGGGATCAC                    64.807692
# SRR1853181_GGCACAGAGCCA                    61.635220
#
#                          pct_counts_in_top_500_genes
# SRR1853184_CTTTACTTGGTC                    39.741661
# SRR1853184_CCGCTCTAAAAG                    46.945903
# SRR1853184_CGGCACAGTGGA                    41.041166
# SRR1853184_GATGCCGGAATG                    35.686275
# SRR1853184_AGGGCTCGCGAC                    47.338357
# ...                                              ...
# SRR1853181_GTCCGCGTCTCT                   100.000000
# SRR1853181_GGAAAACGACTG                   100.000000
# SRR1853181_GCCCAGAAATCT                   100.000000
# SRR1853181_TGGTGGGATCAC                   100.000000
# SRR1853181_GGCACAGAGCCA                   100.000000
#
# [49293 rows x 8 columns]

# %%
df_merged.median()
# Out:
# n_genes_by_counts              671.000000
# log1p_n_genes_by_counts          6.510258
# total_counts                   952.000000
# log1p_total_counts               6.859615
# pct_counts_in_top_50_genes      23.401950
# pct_counts_in_top_100_genes     34.064213
# pct_counts_in_top_200_genes     49.536178
# pct_counts_in_top_500_genes     81.986900
# dtype: float64

# %% [markdown]
# I can now also write a drop-seq barcode list!

# %%
df_merged['barcode'] = [df_merged.index[x].split('_')[1] for x in range(len(df_merged.index))]

# %%
df_merged['barcode'].to_csv('drop-seq_macosko_whitelist.txt', index=False, header=None)

# %% [markdown]
# Using uniq -u $whitelist | wc -l, I found that this barcode list is unique. Remap using this whitelist now.

# %% [markdown]
# # indrop

# %% [markdown]
# For indrop, we take a slightly different approach. We mapped all the pooled data. We read the large unfiltered matrix. We then take the top 1 428 898 458 reads / 52738 = 27094 cells to match hydrop's read depth.

# %%
mtx_dir = 'demultiplexed_indrop_index/merged.Solo.out/Gene/raw/'

# %%
# !gzip demultiplexed_indrop_index/merged.Solo.out/Gene/raw/*

# %%
sample = 'merged'
adata = sc.read_10x_mtx(
    mtx_dir,  # the directory with the `.mtx` file
    var_names="gene_symbols",  # use gene symbols for the variable names (variables-axis index)
    cache=True,
    )  # write a cache file for faster subsequent reading
adata.obs_names = sample + '_' + adata.obs_names
adata.var_names_make_unique()
sc.pp.calculate_qc_metrics(adata, inplace=True)
adata.obs.sort_values(by='n_genes_by_counts', ascending=False, inplace=True)
# Out:
# ... reading from cache file cache/demultiplexed_indrop_index-merged.Solo.out-Gene-raw-matrix.h5ad

# %%
adata[0:31293-1].obs
# Out:
#                                    n_genes_by_counts  log1p_n_genes_by_counts  \
# merged_CTCCTCCA_ATTAGACG_TGTTCCAG               8136                 9.004177
# merged_GGCGACAA_TCTTACGC_GCGCATTC               8129                 9.003316
# merged_CAAGGTAC_ATTAGACG_ATCCGCTA               7448                 8.915835
# merged_AAGGGACC_ATAGCCTT_CCATTTGA               6867                 8.834628
# merged_GGCCCAAT_ACTCTAGG_TTGTGACT               6837                 8.830251
# ...                                              ...                      ...
# merged_GGTTGAGA_CGGAGAGA_TCGGTTTA                418                 6.037871
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                418                 6.037871
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                418                 6.037871
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                418                 6.037871
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                418                 6.037871
#
#                                    total_counts  log1p_total_counts  \
# merged_CTCCTCCA_ATTAGACG_TGTTCCAG       41203.0           10.626290
# merged_GGCGACAA_TCTTACGC_GCGCATTC       38021.0           10.545920
# merged_CAAGGTAC_ATTAGACG_ATCCGCTA       27611.0           10.226006
# merged_AAGGGACC_ATAGCCTT_CCATTTGA       25914.0           10.162578
# merged_GGCCCAAT_ACTCTAGG_TTGTGACT       24172.0           10.092992
# ...                                         ...                 ...
# merged_GGTTGAGA_CGGAGAGA_TCGGTTTA         476.0            6.167517
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA         491.0            6.198479
# merged_AAGAAGGT_ATTAGACG_TAACCCGT         479.0            6.173786
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG         479.0            6.173786
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG         484.0            6.184149
#
#                                    pct_counts_in_top_50_genes  \
# merged_CTCCTCCA_ATTAGACG_TGTTCCAG                    8.564910
# merged_GGCGACAA_TCTTACGC_GCGCATTC                    8.784619
# merged_CAAGGTAC_ATTAGACG_ATCCGCTA                    9.836659
# merged_AAGGGACC_ATAGCCTT_CCATTTGA                   10.963186
# merged_GGCCCAAT_ACTCTAGG_TTGTGACT                   11.662254
# ...                                                       ...
# merged_GGTTGAGA_CGGAGAGA_TCGGTTTA                   22.689076
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                   25.050916
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                   23.173278
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                   23.173278
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                   23.966942
#
#                                    pct_counts_in_top_100_genes  \
# merged_CTCCTCCA_ATTAGACG_TGTTCCAG                    14.045094
# merged_GGCGACAA_TCTTACGC_GCGCATTC                    14.284211
# merged_CAAGGTAC_ATTAGACG_ATCCGCTA                    14.975915
# merged_AAGGGACC_ATAGCCTT_CCATTTGA                    16.975380
# merged_GGCCCAAT_ACTCTAGG_TTGTGACT                    17.160351
# ...                                                        ...
# merged_GGTTGAGA_CGGAGAGA_TCGGTTTA                    33.193277
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                    35.234216
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                    33.611691
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                    33.611691
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                    34.297521
#
#                                    pct_counts_in_top_200_genes  \
# merged_CTCCTCCA_ATTAGACG_TGTTCCAG                    21.556683
# merged_GGCGACAA_TCTTACGC_GCGCATTC                    21.929986
# merged_CAAGGTAC_ATTAGACG_ATCCGCTA                    21.889827
# merged_AAGGGACC_ATAGCCTT_CCATTTGA                    24.507988
# merged_GGCCCAAT_ACTCTAGG_TTGTGACT                    24.652490
# ...                                                        ...
# merged_GGTTGAGA_CGGAGAGA_TCGGTTTA                    54.201681
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                    55.600815
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                    54.488518
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                    54.488518
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                    54.958678
#
#                                    pct_counts_in_top_500_genes
# merged_CTCCTCCA_ATTAGACG_TGTTCCAG                    35.363930
# merged_GGCGACAA_TCTTACGC_GCGCATTC                    36.009048
# merged_CAAGGTAC_ATTAGACG_ATCCGCTA                    35.478614
# merged_AAGGGACC_ATAGCCTT_CCATTTGA                    38.666358
# merged_GGCCCAAT_ACTCTAGG_TTGTGACT                    38.528049
# ...                                                        ...
# merged_GGTTGAGA_CGGAGAGA_TCGGTTTA                   100.000000
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                   100.000000
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                   100.000000
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                   100.000000
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                   100.000000
#
# [31292 rows x 8 columns]

# %% [markdown]
# 65945800 UMIs/1428898458 reads = 4.46%

# %%
adata[27094:31293-1].obs
# Out:
#                                    n_genes_by_counts  log1p_n_genes_by_counts  \
# merged_AAGGATGA_CTAGTCGA_CCGCAACT                489                 6.194405
# merged_TGGCTAGT_CGGAGAGA_AAAGTCGG                489                 6.194405
# merged_CAATTCTC_TAAGGCTC_AAACCTCC                489                 6.194405
# merged_ACATCTCG_ACTCTAGG_TACAAACT                489                 6.194405
# merged_CAGTTTAA_ATTAGACG_TCTAGCAG                489                 6.194405
# ...                                              ...                      ...
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                418                 6.037871
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                418                 6.037871
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                418                 6.037871
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                418                 6.037871
# merged_AGGCCGAA_CTTAATAG_GTGGAGCT                418                 6.037871
#
#                                    total_counts  log1p_total_counts  \
# merged_AAGGATGA_CTAGTCGA_CCGCAACT         573.0            6.352629
# merged_TGGCTAGT_CGGAGAGA_AAAGTCGG         592.0            6.385194
# merged_CAATTCTC_TAAGGCTC_AAACCTCC         591.0            6.383507
# merged_ACATCTCG_ACTCTAGG_TACAAACT         579.0            6.363028
# merged_CAGTTTAA_ATTAGACG_TCTAGCAG         570.0            6.347389
# ...                                         ...                 ...
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA         491.0            6.198479
# merged_AAGAAGGT_ATTAGACG_TAACCCGT         479.0            6.173786
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG         479.0            6.173786
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG         484.0            6.184149
# merged_AGGCCGAA_CTTAATAG_GTGGAGCT         501.0            6.218600
#
#                                    pct_counts_in_top_50_genes  \
# merged_AAGGATGA_CTAGTCGA_CCGCAACT                   20.593368
# merged_TGGCTAGT_CGGAGAGA_AAAGTCGG                   22.804054
# merged_CAATTCTC_TAAGGCTC_AAACCTCC                   23.350254
# merged_ACATCTCG_ACTCTAGG_TACAAACT                   20.725389
# merged_CAGTTTAA_ATTAGACG_TCTAGCAG                   21.929825
# ...                                                       ...
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                   25.050916
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                   23.173278
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                   23.173278
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                   23.966942
# merged_AGGCCGAA_CTTAATAG_GTGGAGCT                   23.153693
#
#                                    pct_counts_in_top_100_genes  \
# merged_AAGGATGA_CTAGTCGA_CCGCAACT                    32.111693
# merged_TGGCTAGT_CGGAGAGA_AAAGTCGG                    34.290541
# merged_CAATTCTC_TAAGGCTC_AAACCTCC                    34.179357
# merged_ACATCTCG_ACTCTAGG_TACAAACT                    32.815199
# merged_CAGTTTAA_ATTAGACG_TCTAGCAG                    31.754386
# ...                                                        ...
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                    35.234216
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                    33.611691
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                    33.611691
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                    34.297521
# merged_AGGCCGAA_CTTAATAG_GTGGAGCT                    36.526946
#
#                                    pct_counts_in_top_200_genes  \
# merged_AAGGATGA_CTAGTCGA_CCGCAACT                    49.563700
# merged_TGGCTAGT_CGGAGAGA_AAAGTCGG                    51.182432
# merged_CAATTCTC_TAAGGCTC_AAACCTCC                    51.099831
# merged_ACATCTCG_ACTCTAGG_TACAAACT                    50.086356
# merged_CAGTTTAA_ATTAGACG_TCTAGCAG                    49.298246
# ...                                                        ...
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                    55.600815
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                    54.488518
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                    54.488518
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                    54.958678
# merged_AGGCCGAA_CTTAATAG_GTGGAGCT                    56.487026
#
#                                    pct_counts_in_top_500_genes
# merged_AAGGATGA_CTAGTCGA_CCGCAACT                        100.0
# merged_TGGCTAGT_CGGAGAGA_AAAGTCGG                        100.0
# merged_CAATTCTC_TAAGGCTC_AAACCTCC                        100.0
# merged_ACATCTCG_ACTCTAGG_TACAAACT                        100.0
# merged_CAGTTTAA_ATTAGACG_TCTAGCAG                        100.0
# ...                                                        ...
# merged_TAGTCTCT_TCTTACGC_ACAGCGGA                        100.0
# merged_AAGAAGGT_ATTAGACG_TAACCCGT                        100.0
# merged_CGGTGAGT_ATAGCCTT_AGTGAAAG                        100.0
# merged_GGACTTCT_TAAGGCTC_TAGCCTCG                        100.0
# merged_AGGCCGAA_CTTAATAG_GTGGAGCT                        100.0
#
# [4199 rows x 8 columns]

# %% [markdown]
# 63744212 UMIs/1428898458 reads = 4.46%

# %%
adata = adata[0:27094-1]
adata.obs.to_csv('indrop' + sample + '_adata.tsv', sep='\t', header=True)

# %%
adata.obs.median()
# Out:
# n_genes_by_counts              1321.000000
# log1p_n_genes_by_counts           7.186901
# total_counts                   1920.000000
# log1p_total_counts                7.560601
# pct_counts_in_top_50_genes       17.385621
# pct_counts_in_top_100_genes      25.818918
# pct_counts_in_top_200_genes      37.254902
# pct_counts_in_top_500_genes      58.153242
# dtype: float64
